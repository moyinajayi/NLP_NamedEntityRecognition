# %%
from sklearn.datasets import fetch_20newsgroups
from pprint import pprint
import pandas as pd

# %%
dataset = fetch_20newsgroups(subset='all', shuffle=False, random_state=32, remove=('headers', 'footers', 'quotes'))
dataset.keys()
# Out:
# dict_keys(['data', 'filenames', 'target_names', 'target', 'DESCR'])

# %%
## Get data  from dictionary and list of target names
#dataset['data']
pprint(dataset.target_names)
# Out:
# ['alt.atheism',
#  'comp.graphics',
#  'comp.os.ms-windows.misc',
#  'comp.sys.ibm.pc.hardware',
#  'comp.sys.mac.hardware',
#  'comp.windows.x',
#  'misc.forsale',
#  'rec.autos',
#  'rec.motorcycles',
#  'rec.sport.baseball',
#  'rec.sport.hockey',
#  'sci.crypt',
#  'sci.electronics',
#  'sci.med',
#  'sci.space',
#  'soc.religion.christian',
#  'talk.politics.guns',
#  'talk.politics.mideast',
#  'talk.politics.misc',
#  'talk.religion.misc']

# %%
len(dataset.target_names)
# Out:
# 20

# %%
dataset.target.shape
# Out:
# (18846,)

# %%
df = pd.DataFrame({'News':dataset.data, 'Label': dataset.target})
df.head()
# Out:
#                                                 News  Label
# 0  \nmorgan and guzman will have era's 1 run high...      9
# 1  Well, I just got my Centris 610 yesterday.  It...      4
# 2  Archive-name: cryptography-faq/part10\nLast-mo...     11
# 3  To the best of my knowledge there aren't any p...      4
# 4  \n\nI think that domestication will change beh...      0

# %%
#Assign Label names based on target names in dataset
df['Label_name'] = df['Label'].apply(lambda x: dataset.target_names[x])
df.head()
# Out:
#                                                 News  Label  \
# 0  \nmorgan and guzman will have era's 1 run high...      9
# 1  Well, I just got my Centris 610 yesterday.  It...      4
# 2  Archive-name: cryptography-faq/part10\nLast-mo...     11
# 3  To the best of my knowledge there aren't any p...      4
# 4  \n\nI think that domestication will change beh...      0
#
#               Label_name
# 0     rec.sport.baseball
# 1  comp.sys.mac.hardware
# 2              sci.crypt
# 3  comp.sys.mac.hardware
# 4            alt.atheism

# %% [markdown]
# #### Data preprocessing

# %%
#pip install -U gensim
#import required libraries to ease data cleaning
from gensim.utils import tokenize
from gensim.parsing.preprocessing import preprocess_string,strip_tags, strip_punctuation, strip_numeric, remove_stopwords, strip_short
from gensim.corpora.dictionary import Dictionary
from gensim import models

# %%
#help(preprocess_string) # to understand what cleaning dunctions are available
df['Clean_news'] = df['News'].apply(preprocess_string)
df.head()
# Out:
#                                                 News  Label  \
# 0  \nmorgan and guzman will have era's 1 run high...      9
# 1  Well, I just got my Centris 610 yesterday.  It...      4
# 2  Archive-name: cryptography-faq/part10\nLast-mo...     11
# 3  To the best of my knowledge there aren't any p...      4
# 4  \n\nI think that domestication will change beh...      0
#
#               Label_name                                         Clean_news
# 0     rec.sport.baseball  [morgan, guzman, era, run, higher, year, cub, ...
# 1  comp.sys.mac.hardware  [got, centri, yesterdai, took, week, place, or...
# 2              sci.crypt  [archiv, cryptographi, faq, modifi, faq, sci, ...
# 3  comp.sys.mac.hardware  [best, knowledg, aren, problem, quadra, blind,...
# 4            alt.atheism  [think, domest, chang, behavior, larg, degre, ...

# %%
filters = [lambda x:x.lower(), strip_punctuation, strip_tags, strip_numeric, remove_stopwords, strip_short]
df['Clean_news1'] = df['News'].apply(lambda x: preprocess_string(x, filters))
df.head()
# Out:
#                                                 News  Label  \
# 0  \nmorgan and guzman will have era's 1 run high...      9
# 1  Well, I just got my Centris 610 yesterday.  It...      4
# 2  Archive-name: cryptography-faq/part10\nLast-mo...     11
# 3  To the best of my knowledge there aren't any p...      4
# 4  \n\nI think that domestication will change beh...      0
#
#               Label_name                                         Clean_news  \
# 0     rec.sport.baseball  [morgan, guzman, era, run, higher, year, cub, ...
# 1  comp.sys.mac.hardware  [got, centri, yesterdai, took, week, place, or...
# 2              sci.crypt  [archiv, cryptographi, faq, modifi, faq, sci, ...
# 3  comp.sys.mac.hardware  [best, knowledg, aren, problem, quadra, blind,...
# 4            alt.atheism  [think, domest, chang, behavior, larg, degre, ...
#
#                                          Clean_news1
# 0  [morgan, guzman, era, run, higher, year, cubs,...
# 1  [got, centris, yesterday, took, weeks, placing...
# 2  [archive, cryptography, faq, modified, faq, sc...
# 3  [best, knowledge, aren, problems, quadras, bli...
# 4  [think, domestication, change, behavior, large...

# %%
dataset_dictionary = Dictionary(df['Clean_news1'])
len(dataset_dictionary)
# Out:
# 99291

# %%
print(dataset_dictionary.token2id)
# Out:
# {'castillo': 0, 'cubs': 1, 'era': 2, 'good': 3, 'guzman': 4, 'harkey': 5, 'hibbard': 6, 'higher': 7, 'idiots': 8, 'morgan': 9, 'pitch': 10, 'pitcher': 11, 'run': 12, 'stud': 13, 'think': 14, 'won': 15, 'year': 16, 'alright': 17, 'annoying': 18, 'apple': 19, 'appologized': 20, 'awful': 21, 'backlogged': 22, 'big': 23, 'boot': 24, 'buttons': 25, 'cable': 26, 'centri': 27, 'centris': 28, 'come': 29, 'complain': 30, 'connected': 31, 'control': 32, 'convenient': 33, 'deal': 34, 'dealer': 35, 'decided': 36, 'dissappionted': 37, 'drive': 38, 'ethernet': 39, 'exceptions': 40, 'exchange': 41, 'fast': 42, 'feature': 43, 'functions': 44, 'got': 45, 'great': 46, 'happy': 47, 'hard': 48, 'having': 49, 'heard': 50, 'high': 51, 'interupt': 52, 'keyboard': 53, 'know': 54, 'lack': 55, 'literature': 56, 'location': 57, 'loose': 58, 'machine': 59, 'mentioned': 60, 'nosy': 61, 'open': 62, 'order': 63, 'ordered': 64, 'partially': 65, 'pissed': 66, 'pitched': 67, 'placing': 68, 'power': 69, 'powering': 70, 'price': 71, 'reset': 72, 'rutgers': 73, 'saw': 74, 'screen': 75, 'scsi': 76, 'seen': 77, 'shipping': 78, 'soft': 79, 'store': 80, 'substituted': 81, 'substitution': 82, 'swapped': 83, 'time': 84, 'tojump': 85, 'took': 86, 'tried': 87, 'try': 88, 'wanted': 89, 'wasn': 90, 'way': 91, 'weeks': 92, 'whine': 93, 'wierd': 94, 'wouldn': 95, 'yesterday': 96, 'abridged': 97, 'abstract': 98, 'abu': 99, 'academic': 100, 'acm': 101, 'addison': 102, 'address': 103, 'advances': 104, 'aegean': 105, 'afips': 106, 'age': 107, 'agency': 108, 'alan': 109, 'algorithm': 110, 'algorithms': 111, 'alternating': 112, 'america': 113, 'american': 114, 'analysis': 115, 'andelman': 116, 'anderson': 117, 'andrew': 118, 'ang': 119, 'angluin': 120, 'annual': 121, 'anonymous': 122, 'ansi': 123, 'answering': 124, 'answers': 125, 'applications': 126, 'archive': 127, 'areas': 128, 'arithmetic': 129, 'art': 130, 'artech': 131, 'articles': 132, 'ask': 133, 'assoc': 134, 'association': 135, 'attn': 136, 'auscrypt': 137, 'austcrypt': 138, 'authentication': 139, 'authors': 140, 'available': 141, 'balenson': 142, 'bamfd': 143, 'bamford': 144, 'based': 145, 'bek': 146, 'beker': 147, 'bell': 148, 'ben': 149, 'bennett': 150, 'ber': 151, 'bergen': 152, 'bet': 153, 'beta': 154, 'beth': 155, 'bia': 156, 'bih': 157, 'biham': 158, 'bin': 159, 'black': 160, 'block': 161, 'book': 162, 'books': 163, 'box': 164, 'boxes': 165, 'boy': 166, 'boyar': 167, 'bra': 168, 'brassard': 169, 'breaking': 170, 'bri': 171, 'brickell': 172, 'british': 173, 'bro': 174, 'broadway': 175, 'brown': 176, 'bsd': 177, 'bureau': 178, 'burnett': 179, 'bytes': 180, 'cae': 181, 'caelli': 182, 'callimahos': 183, 'cam': 184, 'cambridge': 185, 'campbell': 186, 'carl': 187, 'cbw': 188, 'certificate': 189, 'certification': 190, 'chalmers': 191, 'chamber': 192, 'chinacrypt': 193, 'cipher': 194, 'ciphers': 195, 'ciphertext': 196, 'cited': 197, 'claredon': 198, 'classical': 199, 'codebreakers': 200, 'codes': 201, 'com': 202, 'command': 203, 'comment': 204, 'commerce': 205, 'communication': 206, 'communications': 207, 'comp': 208, 'company': 209, 'comparison': 210, 'complete': 211, 'complexity': 212, 'computational': 213, 'computers': 214, 'computing': 215, 'conference': 216, 'construct': 217, 'contain': 218, 'contemporary': 219, 'contents': 220, 'copies': 221, 'copyrighted': 222, 'correct': 223, 'course': 224, 'cover': 225, 'cracking': 226, 'criteria': 227, 'crypt': 228, 'cryptanalysis': 229, 'cryptanalytics': 230, 'crypto': 231, 'cryptogram': 232, 'cryptograms': 233, 'cryptographic': 234, 'cryptography': 235, 'cryptologia': 236, 'cryptologic': 237, 'cryptology': 238, 'cryptosystems': 239, 'cup': 240, 'data': 241, 'dav': 242, 'david': 243, 'davida': 244, 'davies': 245, 'davio': 246, 'dawson': 247, 'days': 248, 'dea': 249, 'deavours': 250, 'december': 251, 'dedham': 252, 'defense': 253, 'den': 254, 'denning': 255, 'department': 256, 'dependence': 257, 'des': 258, 'design': 259, 'destoo': 260, 'details': 261, 'dif': 262, 'differential' ...

# %%
dataset_corpus_bow = [dataset_dictionary.doc2bow(text) for text in df['Clean_news1']]
len(dataset_corpus_bow)
# Out:
# 18846

# %%
print(dataset_corpus_bow[1])
# Out:
# [(17, 1), (18, 1), (19, 2), (20, 1), (21, 1), (22, 1), (23, 1), (24, 1), (25, 1), (26, 1), (27, 1), (28, 1), (29, 2), (30, 1), (31, 1), (32, 1), (33, 1), (34, 1), (35, 1), (36, 1), (37, 1), (38, 2), (39, 3), (40, 1), (41, 1), (42, 1), (43, 1), (44, 1), (45, 1), (46, 2), (47, 1), (48, 2), (49, 1), (50, 1), (51, 1), (52, 1), (53, 1), (54, 1), (55, 1), (56, 1), (57, 1), (58, 1), (59, 1), (60, 2), (61, 1), (62, 1), (63, 2), (64, 1), (65, 1), (66, 1), (67, 1), (68, 1), (69, 2), (70, 1), (71, 1), (72, 1), (73, 1), (74, 1), (75, 1), (76, 1), (77, 1), (78, 2), (79, 1), (80, 1), (81, 1), (82, 1), (83, 1), (84, 1), (85, 1), (86, 1), (87, 1), (88, 1), (89, 1), (90, 1), (91, 1), (92, 1), (93, 1), (94, 1), (95, 1), (96, 1)]
